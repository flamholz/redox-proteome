# %%
import cobra
import numpy as np
import pandas as pd
import seaborn as sns
import viz

from matplotlib import pyplot as plt

colors = viz.plotting_style()
lin_colors = colors.values()

plt.style.use('style.mpl')

# TODO: put all this into a script in munge/

# %%
# Load the model -- Elad recommends iML1515
coli_model = cobra.io.read_sbml_model("../models/iML1515.xml")

# Gurobi is default, appears to be slower? 
coli_model.solver = 'glpk'
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-03

# %%
coli_model.slim_optimize()
# Out:
# 0.8769972144269896

# %%
# Check the maintenance ATP requirement --
# notice that its LB and UB are not equal
coli_model.reactions.ATPM
# Out:
# <Reaction ATPM at 0x7f7e344b1820>

# %%
# Set up a medium without C or electron acceptors
my_medium = dict(coli_model.medium)
my_medium['EX_glc__D_e'] = 0 
my_medium['EX_o2_e'] = 0

# %%
# List of electron acceptors to test
e_acceptors = {
    'NO3': 'EX_no3_e',
    'O2': 'EX_o2_e',
    #'fumarate': 'EX_fum_e',
    'TMAO': 'EX_tmao_e',
    'DMSO': 'EX_dmso_e',
    'fermentation': None,
}

# Get the C exchanges from the model
c_exchanges = {}
for e in coli_model.exchanges:
    for m in e.metabolites.keys():
        if m.elements.get('C', 0) > 0:
            c_exchanges[e.id] = m.name

# Manual list of C sources to try
c_exchanges2test = [
    dict(name='glucose', type='sugar', ex_id='EX_glc__D_e'),
    dict(name='acetate', type='organic acid', ex_id='EX_ac_e'),
    dict(name='glycerol', type='sugar alcohol', ex_id='EX_glyc_e'),
    dict(name='succinate', type='organic acid', ex_id='EX_succ_e'),
    dict(name='fumarate', type='organic acid', ex_id='EX_fum_e'),
    dict(name='pyruvate', type='organic acid', ex_id='EX_pyr_e'),
    dict(name='lactate', type='organic acid', ex_id='EX_lac__D_e'),
    dict(name='ethanol', type='alcohol', ex_id='EX_etoh_e'),
    dict(name='alanine', type='amino acid', ex_id='EX_ala__L_e'),
    dict(name='glycine', type='amino acid', ex_id='EX_gly_e'),
    dict(name='serine', type='amino acid', ex_id='EX_ser__L_e'),
    dict(name='threonine', type='amino acid', ex_id='EX_thr__L_e'),
    dict(name='valine', type='amino acid', ex_id='EX_val__L_e'),
    dict(name='leucine', type='amino acid', ex_id='EX_leu__L_e'),
    dict(name='isoleucine', type='amino acid', ex_id='EX_ile__L_e'),
    dict(name='aspartate', type='amino acid', ex_id='EX_asp__L_e'),
    dict(name='glutamate', type='amino acid', ex_id='EX_glu__L_e'),
    dict(name='asparagine', type='amino acid', ex_id='EX_asn__L_e'),
    dict(name='glutamine', type='amino acid', ex_id='EX_gln__L_e'),
    dict(name='cysteine', type='amino acid', ex_id='EX_cys__L_e'),
    dict(name='methionine', type='amino acid', ex_id='EX_met__L_e'),
    dict(name='lysine', type='amino acid', ex_id='EX_lys__L_e'),
    dict(name='arginine', type='amino acid', ex_id='EX_arg__L_e'),
    dict(name='histidine', type='amino acid', ex_id='EX_his__L_e'),
    dict(name='phenylalanine', type='amino acid', ex_id='EX_phe__L_e'),
    dict(name='tyrosine', type='amino acid', ex_id='EX_tyr__L_e'),
    dict(name='tryptophan', type='amino acid', ex_id='EX_trp__L_e'),
    dict(name='cytosine', type='nucleobase', ex_id='EX_cytd_e'),
    dict(name='uracil', type='nucleobase', ex_id='EX_ura_e'),
    dict(name='adenine', type='nucleobase', ex_id='EX_adn_e'),
    dict(name='guanine', type='nucleobase', ex_id='EX_gua_e'),
    dict(name='thymine', type='nucleobase', ex_id='EX_thym_e'),
    dict(name='uridine', type='nucleoside', ex_id='EX_uri_e'),
    dict(name='cytidine', type='nucleoside', ex_id='EX_cytd_e'),
    dict(name='adenosine', type='nucleoside', ex_id='EX_adn_e'),
    dict(name='guanosine', type='nucleoside', ex_id='EX_gua_e'),
    dict(name='thymidine', type='nucleoside', ex_id='EX_thym_e'),
    dict(name='inosine', type='nucleoside', ex_id='EX_inost_e'),
    dict(name='xanthosine', type='nucleoside', ex_id='EX_xan_e'),
    dict(name='sucrose', type='sugar', ex_id='EX_sucr_e'),
    dict(name='trehalose', type='sugar', ex_id='EX_tre_e'),
    dict(name='maltose', type='sugar', ex_id='EX_malt_e'),
    dict(name='gluconate', type='sugar acid', ex_id='EX_gal_e'),
    dict(name='glucuronate', type='sugar acid', ex_id='EX_glcur_e'),
    dict(name='galacturonate', type='sugar acid', ex_id='EX_galur_e'),
    dict(name='glucarate', type='sugar acid', ex_id='EX_glcr_e'),
    dict(name='rhamnose', type='sugar', ex_id='EX_rmn_e'),
    dict(name='arabinose', type='sugar', ex_id='EX_arab__L_e'),
    dict(name='xylose', type='sugar', ex_id='EX_xyl__D_e'),
    dict(name='fucose', type='sugar', ex_id='EX_fuc__L_e'),
    dict(name='mannose', type='sugar', ex_id='EX_man_e'),
    dict(name='fructose', type='sugar', ex_id='EX_fru_e'),
    dict(name='sorbitol', type='sugar alcohol', ex_id='EX_sbt__D_e'),
    dict(name='hexadecenoate', type='fatty acid', ex_id='EX_hdcea_e'),
    dict(name='tetradecenoate', type='fatty acid', ex_id='EX_ttdcea_e'),
    dict(name='tetradecanoate', type='fatty acid', ex_id='EX_ttdca_e'),
    dict(name='octadecanoate', type='fatty acid', ex_id='EX_ocdca_e'),
    dict(name='octadecenoate', type='fatty acid', ex_id='EX_ocdcea_e'),
    dict(name='hexanoate', type='fatty acid', ex_id='EX_hxa_e'),
    dict(name='decanoate', type='fatty acid', ex_id='EX_dca_e'),
    dict(name='octanoate', type='fatty acid', ex_id='EX_octa_e'),
    dict(name='hexadecanoate', type='fatty acid', ex_id='EX_hdca_e'),
    dict(name='dodecanoate', type='fatty acid', ex_id='EX_ddca_e'),
    dict(name='3-hydroxypropanoate', type='organic acid', ex_id='EX_3hpp_e'),
    dict(name='phenylacealdehyde', type='aromatic', ex_id='EX_pacald_e'),
    dict(name='phenylpropanoate', type='aromatic', ex_id='EX_pppn_e'),
    dict(name='dopamine', type='aromatic', ex_id='EX_dopa_e'),
    dict(name='tyramine', type='aromatic', ex_id='EX_tym_e'),
]


# Check that all C sources are in the model
for c in c_exchanges2test:
    if c['ex_id'] not in c_exchanges:
        print(c['name'], 'not found')

# %%
for ex_id, ex_name in c_exchanges.items():
    print(ex_id, ex_name)
# Out:
# EX_co2_e CO2 CO2
# EX_met__L_e L-Methionine
# EX_metsox_S__L_e L-Methionine Sulfoxide
# EX_acgam_e N-Acetyl-D-glucosamine
# EX_cellb_e Cellobiose
# EX_crn_e L-Carnitine
# EX_hxan_e Hypoxanthine
# EX_ile__L_e L-Isoleucine
# EX_chol_e Choline C5H14NO
# EX_lac__L_e L-Lactate
# EX_leu__L_e L-Leucine
# EX_glcn_e D-Gluconate
# EX_orn_e Ornithine
# EX_gln__L_e L-Glutamine
# EX_pro__L_e L-Proline
# EX_glyc_e Glycerol
# EX_man_e D-Mannose
# EX_ade_e Adenine
# EX_4abut_e 4-Aminobutanoate
# EX_ac_e Acetate
# EX_akg_e 2-Oxoglutarate
# EX_ala__L_e L-Alanine
# EX_arg__L_e L-Arginine
# EX_asp__L_e L-Aspartate
# EX_pyr_e Pyruvate
# EX_succ_e Succinate
# EX_thymd_e Thymidine C10H14N2O5
# EX_rib__D_e D-Ribose
# EX_tyr__L_e L-Tyrosine
# EX_cytd_e Cytidine
# EX_dcyt_e Deoxycytidine
# EX_fum_e Fumarate
# EX_sbt__D_e D-Sorbitol
# EX_glu__L_e L-Glutamate
# EX_gua_e Guanine
# EX_btn_e Biotin
# EX_ptrc_e Putrescine
# EX_spmd_e Spermidine
# EX_thym_e Thymine C5H6N2O2
# EX_xtsn_e Xanthosine
# EX_glc__D_e D-Glucose
# EX_alltn_e Allantoin
# EX_ura_e Uracil
# EX_val__L_e L-Valine
# EX_xan_e Xanthine
# EX_dgsn_e Deoxyguanosine
# EX_arab__L_e L-Arabinose
# EX_fru_e D-Fructose
# EX_gal_e D-Galactose
# EX_xyl__D_e D-Xylose
# EX_duri_e Deoxyuridine
# EX_for_e Formate
# EX_gly_e Glycine
# EX_lys__L_e L-Lysine
# EX_ser__L_e L-Serine
# EX_thm_e Thiamin
# EX_trp__L_e L-Tryptophan
# EX_din_e Deoxyinosine
# EX_fmn_e FMN C17H19N4O9P
# EX_gthox_e Oxidized glutathione
# EX_tmao_e Trimethylamine N-oxide
# EX_acald_e Acetaldehyde
# EX_melib_e Melibiose C12H22O11
# EX_sucr_e Sucrose C12H22O11
# EX_tre_e Trehalose
# EX_hdcea_e Hexadecenoate (n-C16:1)
# EX_lac__D_e D-Lactate
# EX_ttdcea_e Tetradecenoate (n-C14:1)
# EX_gthrd_e Reduced glutathione
# EX_26dap__M_e Meso-2,6-Diaminoheptanedioate
# EX_acnam_e N-Acetylneuraminate
# EX_amp_e AMP C10H12N5O7P
# EX_dha_e Dihydroxyacetone
# EX_fuc__L_e L-Fucose
# EX_met__D_e D-Methionine
# EX_tartr__L_e L-tartrate
# EX_taur_e Taurine C2H7NO3S
# EX_maltpt_e Maltopentaose
# EX_glyald_e D-Glyceraldehyde
# EX_glcur_e D-Glucuronate
# EX_nmn_e NMN C11H14N2O8P
# EX_urea_e Urea CH4N2O
# EX_f6p_e D-Fructose 6-phosphate
# EX_rmn_e L-Rhamnose
# EX_ttdca_e Tetradecanoate (n-C14:0)
# EX_glyclt_e Glycolate C2H3O3
# EX_g6p_e D-Glucose 6-phosphate
# EX_2ddglcn_e 2-Dehydro-3-deoxy-D-gluconate
# EX_mmet_e S-Methyl-L-methionine
# EX_galct__D_e D-Galactarate
# EX_idon__L_e L-Idonate
# EX_indole_e Indole
# EX_3hcinnm_e 3-hydroxycinnamic acid
# EX_acac_e Acetoacetate
# EX_acmana_e N-Acetyl-D-mannosamine
# EX_galur_e D-Galacturonate
# EX_adn_e Adenosine
# EX_ins_e Inosine
# EX_glyc3p_e Glycerol 3-phosphate
# EX_but_e Butyrate (n-C4:0)
# EX_lcts_e Lactose C12H22O11
# EX_ocdca_e Octadecanoate (n-C18:0)
# EX_cbl1_e Cob(I)alamin
# EX_nac_e Nicotinate
# EX_dad_2_e Deoxyadenosine
# EX_ser__D_e D-Serine
# EX_gam6p_e D-Glucosamine 6-phosphate
# EX_15dap_e 1,5-Diaminopentane
# EX_ocdcea_e Octadecenoate (n-C18:1)
# EX_cynt_e Cyanate
# EX_galctn__D_e D-Galactonate
# EX_glyb_e Glycine betaine
# EX_ascb__L_e L-Ascorbate
# EX_ala_B_e Beta-Alanine
# EX_agm_e Agmatine
# EX_minohp_e Myo-Inositol hexakisphosphate
# EX_hxa_e Hexanoate (n-C6:0)
# EX_lyx__L_e L-Lyxose
# EX_acmum_e N-Acetylmuramate
# EX_dca_e Decanoate (n-C10:0)
# EX_all__D_e D-Allose
# EX_octa_e Octanoate (n-C8:0)
# EX_gbbtn_e Gamma-butyrobetaine
# EX_xylu__L_e L-Xylulose
# EX_gdp_e GDP C10H12N5O11P2
# EX_gtp_e GTP C10H12N5O14P3
# EX_tma_e Trimethylamine
# EX_fruur_e D-Fructuronate
# EX_malttr_e Maltotriose C18H32O16
# EX_cbi_e Cobinamide
# EX_arbtn_fe3_e Aerobactin
# EX_cpgn_e Coprogen
# EX_ch4_e Methane
# EX_adocbl_e Adenosylcobalamin
# EX_ppa_e Propionate (n-C3:0)
# EX_fad_e Flavin adenine dinucleotide oxidized
# EX_meoh_e Methanol
# EX_fe3dcit_e Fe(III)dicitrate
# EX_fe3hox_e Fe(III)hydroxamate
# EX_fecrm_e Ferrichrome
# EX_feenter_e Fe-enterobactin
# EX_feoxam_e Generic ferrioxamine-Fe-III
# EX_3amp_e 3  AMP C10H12N5O7P
# EX_3gmp_e Guanosine 3  phosphate C10H12N5O8P
# EX_3ump_e 3  UMP C9H11N2O9P
# EX_glyc__R_e (R)-Glycerate
# EX_eca4colipa_e (enterobacterial common antigen)x4 core oligosaccharide lipid A
# EX_mal__D_e D-Malate
# EX_pheme_e Protoheme C34H30FeN4O4
# EX_mso3_e Methanesulfonate
# EX_23camp_e 2',3'-Cyclic AMP
# EX_23cgmp_e 2',3'-Cyclic GMP
# EX_23cump_e 2',3'-Cyclic UMP
# EX_sulfac_e Sulfoacetate
# EX_butso3_e Butanesulfonate
# EX_ethso3_e Ethanesulfonate
# EX_tym_e Tyramine
# EX_imp_e IMP C10H11N4O8P
# EX_fe3hox_un_e Fe(III)hydoxamate, unloaded
# EX_23dappa_e 2,3-diaminopropionate
# EX_enter_e Enterochelin
# EX_fecrm_un_e Ferrichrome minus Fe(III)
# EX_cgly_e Cys Gly C5H10N2O3S
# EX_chtbs_e N,N'-diacetylchitobiose
# EX_gmp_e GMP C10H12N5O8P
# EX_ump_e UMP C9H11N2O9P
# EX_pydam_e Pyridoxamine
# EX_frulys_e Fructoselysine
# EX_enlipa_e Phosphoethanolamine KDO(2)-lipid (A)
# EX_hacolipa_e Hepta-acylated core oligosaccharide lipid A (E. coli)
# EX_etha_e Ethanolamine
# EX_hdca_e Hexadecanoate (n-C16:0)
# EX_glcr_e D-Glucarate
# EX_ala__D_e D-Alanine
# EX_mnl_e D-Mannitol
# EX_malt_e Maltose C12H22O11
# EX_pnto__R_e (R)-Pantothenate
# EX_asn__L_e L-Asparagine
# EX_cit_e Citrate
# EX_mal__L_e L-Malate
# EX_gam_e D-Glucosamine
# EX_inost_e Myo-Inositol
# EX_phe__L_e L-Phenylalanine
# EX_thr__L_e L-Threonine
# EX_uri_e Uridine
# EX_ddca_e Dodecanoate (n-C12:0)
# EX_r5p_e Alpha-D-Ribose 5-phosphate
# EX_glyc2p_e Glycerol 2-phosphate
# EX_halipa_e Hepta-acylated KDO(2)-lipid (A)
# EX_cmp_e CMP C9H12N3O8P
# EX_malthx_e Maltohexaose
# EX_csn_e Cytosine
# EX_etoh_e Ethanol
# EX_g3pe_e Sn-Glycero-3-phosphoethanolamine
# EX_pacald_e Phenylacetaldehyde
# EX_his__L_e L-Histidine
# EX_dmso_e Dimethyl sulfoxide
# EX_12ppd__S_e (S)-Propane-1,2-diol
# EX_pppn_e Phenylpropanoate
# EX_acgam1p_e N-Acetyl-D-glucosamine 1-phosphate
# EX_galt_e Galactitol
# EX_glcur1p_e D-Glucuronate 1-phosphate
# EX_thrp_e L-Threonine O-3-phosphate
# EX_fald_e Formaldehyde
# EX_pydxn_e Pyridoxine
# EX_acgal_e N-Acetyl-D-galactosamine
# EX_dms_e Dimethyl sulfide
# EX_acgal1p_e N-Acetyl-D-galactosamine 1-phosphate
# EX_cyan_e Hydrogen cyanide
# EX_tyrp_e Phosphotyrosine
# EX_uacgam_e UDP-N-acetyl-D-glucosamine
# EX_udpacgal_e UDP-N-acetyl-D-galactosamine
# EX_udpg_e UDPglucose
# EX_udpgal_e UDPgalactose
# EX_udpglcur_e UDP-D-glucuronate
# EX_14glucan_e 1,4-alpha-D-glucan
# EX_pser__L_e O-Phospho-L-serine
# EX_xmp_e Xanthosine 5'-phosphate
# EX_damp_e DAMP C10H12N5O6P
# EX_dimp_e DIMP C10H12N4O7P
# EX_isetac_e Isethionic acid
# EX_tcynt_e Thiocyanate
# EX_fe3dhbzs_e Ferric 2,3-dihydroxybenzoylserine
# EX_feoxam_un_e Ferroxamine minus Fe(3)
# EX_g3pc_e Sn-Glycero-3-phosphocholine
# EX_g3pg_e Glycerophosphoglycerol
# EX_g3pi_e Sn-Glycero-3-phospho-1-inositol
# EX_g3ps_e Glycerophosphoserine
# EX_peamn_e Phenethylamine
# EX_34dhpac_e 3,4-Dihydroxyphenylacetaldehyde
# EX_cys__L_e L-Cysteine
# EX_gsn_e Guanosine
# EX_orot_e Orotate C5H3N2O4
# EX_manglyc_e 2(alpha-D-Mannosyl)-D-glycerate
# EX_metsox_R__L_e L-methionine-R-sulfoxide
# EX_dgmp_e DGMP C10H12N5O7P
# EX_4hoxpacd_e 4-Hydroxyphenylacetaldehyde
# EX_3hpppn_e 3-(3-hydroxy-phenyl)propionate
# EX_man6p_e D-Mannose 6-phosphate
# EX_maltttr_e Maltotetraose
# EX_alaala_e D-Alanyl-D-alanine
# EX_dtmp_e DTMP C10H13N2O8P
# EX_lipoate_e Lipoate
# EX_pydx_e Pyridoxal
# EX_g1p_e D-Glucose 1-phosphate
# EX_progly_e L-Prolinylglycine
# EX_gal_bD_e Beta D-Galactose
# EX_dump_e DUMP C9H11N2O8P
# EX_12ppd__R_e (R)-Propane-1,2-diol
# EX_gal1p_e Alpha-D-Galactose 1-phosphate
# EX_dcmp_e DCMP C9H12N3O7P
# EX_23ccmp_e 2',3'-Cyclic CMP
# EX_3cmp_e 3  CMP C9H12N3O8P
# EX_urate_e Urate C5H4N4O3
# EX_skm_e Shikimate
# EX_cpgn_un_e Coprogen unloaded (no Fe(III))
# EX_cys__D_e D-Cysteine
# EX_acser_e O-Acetyl-L-serine
# EX_arbtn_e Aerobactin minus Fe3
# EX_dopa_e Dopamine
# EX_tartr__D_e D-tartrate
# EX_galctn__L_e L-Galactonate
# EX_hom__L_e L-Homoserine
# EX_crn__D_e D-Carnitine
# EX_LalaDgluMdapDala_e L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate-D-alanine
# EX_5dglcn_e 5-Dehydro-D-gluconate
# EX_LalaDgluMdap_e L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate
# EX_psclys_e Psicoselysine
# EX_anhgm_e N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramic acid
# EX_ppal_e Propanal
# EX_LalaDglu_e L-alanine-D-glutamate
# EX_5mtr_e 5-Methylthio-D-ribose
# EX_LalaLglu_e L-alanine-L-glutamate
# EX_ttrcyc_e Tetracycline
# EX_mincyc_e Minocycline
# EX_arbt_e Arbutin C12H16O7
# EX_dxylnt_e D-Xylonate
# EX_mththf_e (2R,4S)-2-methyl-2,3,3,4-tetrahydroxytetrahydrofuran
# EX_doxrbcn_e Doxorubicin
# EX_dhps_e 2,3-Dihydroxypropane-1-sulfonate
# EX_fusa_e Fusidic acid
# EX_mepn_e Methylphosphonic acid
# EX_cm_e Chloramphenicol
# EX_novbcn_e Novobiocin
# EX_2dglc_e 2 Deoxy D glucose C6H12O5
# EX_sq_e Sulphoquinovose
# EX_4abzglu_e 4-aminobenzoyl-glutamate
# EX_rfamp_e Rifampin
# EX_metglcur_e 1-O-methyl-Beta-D-glucuronate
# EX_quin_e Quinate
# EX_3hpp_e 3-Hydroxypropanoate

# %%
# Run FBA for all combinations of C and e- acceptors
growth_data = []
for i, (e, e_ex) in enumerate(e_acceptors.items()):   
    for j, c_ex in enumerate(c_exchanges2test):
        tmp_medium = dict(my_medium)
        tmp_medium[c_ex['ex_id']] = 10.0

        # None signals fermentation (no e- acceptor)
        if e_ex is not None:
            tmp_medium[e_ex] = 1000.0

        tmp_model = coli_model.copy()
        tmp_model.medium = tmp_medium

        # Calculate the model's growth rate and save
        opt = tmp_model.optimize()
        mu = opt.objective_value

        mu = tmp_model.slim_optimize()
        growth_data.append(dict(
            e_acceptor=e,
            c_source=c_ex['name'],
            c_source_type=c_ex['type'],
            growth_rate_hr=mu,
            maintenance=opt.fluxes['ATPM'],
        ))
# Out:
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)

# %%
# Convert to a dataframe
long_growth_df = pd.DataFrame(growth_data)

# Binarize growth 
long_growth_df['grows'] = long_growth_df.growth_rate_hr > 0.01
growth_mat_df = long_growth_df.pivot_table(
    index='c_source_type,c_source'.split(','), 
    columns='e_acceptor', values='growth_rate_hr').reset_index()
growth_mat_df = growth_mat_df.fillna(0)

# Drop C sources with no growth at all
no_grow = (growth_mat_df == 0).all(axis=1)
growth_mat_df = growth_mat_df.drop(no_grow.index[no_grow]).sort_values('c_source_type').set_index(
    'c_source_type,c_source'.split(','))

# Save the growth matrix
growth_mat_df.to_csv('../output/iML1515_growth_rate_matrix.csv')

# Make a binary version of the growth matrix for plotting
binary_growth_mat_df = growth_mat_df > 0.001
binary_growth_mat_df.to_csv('../output/iML1515_binary_growth_matrix.csv')

# %%
# Maintenance never exceeds the minimum
# -- see that 6.86 is the only value
print(long_growth_df.maintenance.value_counts())
# Out:
# maintenance
# 6.86    340
# Name: count, dtype: int64

# %%
cols = 'O2,NO3,DMSO,TMAO,fermentation'.split(',')
cmap = sns.color_palette('cividis', as_cmap=True)
cmap.set_bad('white')

plt.figure(figsize=(7.24, 8))
annot = binary_growth_mat_df.replace({True: 'grows', False: 'no growth'})
nice_labels = dict(O2='O$_2$', NO3='NO$_3^{-}$', DMSO='DMSO', TMAO='TMAO', fermentation='fermentation')
xticklabels = [nice_labels.get(x, x) for x in cols]
sns.heatmap(binary_growth_mat_df[cols], annot=annot[cols], cbar=False, fmt='',
            xticklabels=xticklabels, annot_kws=dict(size=7))
plt.xlabel('terminal e$^-$ acceptor')
plt.ylabel('carbon source')
# Out:
# Text(52.65999999999999, 0.5, 'carbon source')

# %%
coli_model = cobra.io.read_sbml_model("../models/iML1515.xml")
coli_model.solver = 'glpk'
coli_model.reactions.ATPM
# Out:
# <Reaction ATPM at 0x7f7e00019a60>

# %%
b_ubs = np.hstack([np.arange(6.87, 10, 0.1), np.logspace(1,3,50)])
print(b_ubs)
lams = np.zeros_like(b_ubs)
for i, ub in enumerate(b_ubs):
    coli_model.reactions.ATPM.upper_bound = ub
    opt = coli_model.optimize()
    gr = opt.objective_value
    lams[i] = gr

lams
# Out:
# [   6.87          6.97          7.07          7.17          7.27
#     7.37          7.47          7.57          7.67          7.77
#     7.87          7.97          8.07          8.17          8.27
#     8.37          8.47          8.57          8.67          8.77
#     8.87          8.97          9.07          9.17          9.27
#     9.37          9.47          9.57          9.67          9.77
#     9.87          9.97         10.           10.98541142   12.06792641
#    13.25711366   14.56348478   15.9985872    17.57510625   19.30697729
#    21.20950888   23.29951811   25.59547923   28.11768698   30.88843596
#    33.93221772   37.2759372    40.94915062   44.98432669   49.41713361
#    54.28675439   59.63623317   65.51285569   71.9685673    79.06043211
#    86.85113738   95.40954763  104.81131342  115.13953993  126.48552169
#   138.94954944  152.64179672  167.68329368  184.20699693  202.35896477
#   222.29964825  244.20530945  268.26957953  294.70517026  323.74575428
#   355.64803062  390.69399371  429.19342601  471.48663635  517.94746792
#   568.9866029   625.05519253  686.648845    754.31200634  828.64277285
#   910.29817799 1000.        ]
# array([0.87699721, 0.87699721, 0.87699721, 0.87699721, 0.87699721,
#        0.87699721, 0.87699721, 0.87699721, 0.87699721, 0.87699721,
#        0.87699721, 0.87699721, 0.87699721, 0.87699721, 0.87699721,
#        0.87699721, 0.87699721, 0.87699721, 0.87699721, 0.87699721,
#        0.87699721, 0.87699721, 0.87699721, 0.87699721, 0.87699721,
#        0.87699721, 0.87699721, 0.87699721, 0.87699721, 0.87699721,
#        0.87699721, 0.87699721, 0.87699721, 0.87699721, 0.87699721,
#        0.87699721, 0.87699721, 0.87699721, 0.87699721, 0.87699721,
#        0.87699721, 0.87699721, 0.87699721, 0.87699721, 0.87699721,
#        0.87699721, 0.87699721, 0.87699721, 0.87699721, 0.87699721,
#        0.87699721, 0.87699721, 0.87699721, 0.87699721, 0.87699721,
#        0.87699721, 0.87699721, 0.87699721, 0.87699721, 0.87699721,
#        0.87699721, 0.87699721, 0.87699721, 0.87699721, 0.87699721,
#        0.87699721, 0.87699721, 0.87699721, 0.87699721, 0.87699721,
#        0.87699721, 0.87699721, 0.87699721, 0.87699721, 0.87699721,
#        0.87699721, 0.87699721, 0.87699721, 0.87699721, 0.87699721,
#        0.87699721, 0.87699721])

# %%
# Similar exercise for EcoliCore2 core model
core_model = cobra.io.read_sbml_model("../models/ECC2_extended_core_updated.xml")
core_model.solver = 'glpk'
core_model.compartments = {'c': 'Internal_Species', 'e': 'External_Species'}

# Set the ATP maintenance to non-zero
core_model.reactions.ATPM.lower_bound = 5
# Out:
# Adding exchange reaction EX_Biomass with default bounds for boundary metabolite: Biomass.
# Adding exchange reaction EX_ca2_ex with default bounds for boundary metabolite: ca2_ex.
# Adding exchange reaction EX_cl_ex with default bounds for boundary metabolite: cl_ex.
# Adding exchange reaction EX_co2_ex with default bounds for boundary metabolite: co2_ex.
# Adding exchange reaction EX_cobalt2_ex with default bounds for boundary metabolite: cobalt2_ex.
# Adding exchange reaction EX_cu2_ex with default bounds for boundary metabolite: cu2_ex.
# Adding exchange reaction EX_fe2_ex with default bounds for boundary metabolite: fe2_ex.
# Adding exchange reaction EX_fe3_ex with default bounds for boundary metabolite: fe3_ex.
# Adding exchange reaction EX_glc_DASH_D_ex with default bounds for boundary metabolite: glc_DASH_D_ex.
# Adding exchange reaction EX_glyc_ex with default bounds for boundary metabolite: glyc_ex.
# Adding exchange reaction EX_h_ex with default bounds for boundary metabolite: h_ex.
# Adding exchange reaction EX_h2o_ex with default bounds for boundary metabolite: h2o_ex.
# Adding exchange reaction EX_k_ex with default bounds for boundary metabolite: k_ex.
# Adding exchange reaction EX_mg2_ex with default bounds for boundary metabolite: mg2_ex.
# Adding exchange reaction EX_mn2_ex with default bounds for boundary metabolite: mn2_ex.
# Adding exchange reaction EX_mobd_ex with default bounds for boundary metabolite: mobd_ex.
# Adding exchange reaction EX_nh4_ex with default bounds for boundary metabolite: nh4_ex.
# Adding exchange reaction EX_ni2_ex with default bounds for boundary metabolite: ni2_ex.
# Adding exchange reaction EX_o2_ex with default bounds for boundary metabolite: o2_ex.
# Adding exchange reaction EX_pi_ex with default bounds for boundary metabolite: pi_ex.
# Adding exchange reaction EX_so4_ex with default bounds for boundary metabolite: so4_ex.
# Adding exchange reaction EX_succ_ex with default bounds for boundary metabolite: succ_ex.
# Adding exchange reaction EX_zn2_ex with default bounds for boundary metabolite: zn2_ex.
# Adding exchange reaction EX_ac_ex with default bounds for boundary metabolite: ac_ex.
# Adding exchange reaction EX_etoh_ex with default bounds for boundary metabolite: etoh_ex.
# Adding exchange reaction EX_for_ex with default bounds for boundary metabolite: for_ex.
# Adding exchange reaction EX_h2_ex with default bounds for boundary metabolite: h2_ex.
# Adding exchange reaction EX_lac_ex with default bounds for boundary metabolite: lac_ex.
# Adding exchange reaction EX_4CRSOL_ex with default bounds for boundary metabolite: 4CRSOL_ex.
# Adding exchange reaction EX_5DRIB_ex with default bounds for boundary metabolite: 5DRIB_ex.
# Adding exchange reaction EX_AMOB_ex with default bounds for boundary metabolite: AMOB_ex.
# Adding exchange reaction EX_MTHTHF_ex with default bounds for boundary metabolite: MTHTHF_ex.
# Adding exchange reaction EX_meoh_ex with default bounds for boundary metabolite: meoh_ex.

# %%
my_medium = core_model.medium.copy()

# Base medium with no carbon and no e- acceptors
# Zero out all the carbon sources
c_sources = 'EX_glc_DASH_D_ex,EX_glyc_ex,EX_ac_ex,EX_succ_ex'.split(',')
for c_source in c_sources:
    my_medium[c_source] = 0

# Zero out all the electron acceptors
e_acceptors = 'EX_o2_ex'.split(',')
for e_acceptor in e_acceptors:
    my_medium[e_acceptor] = 0

my_medium
# Out:
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# {'EX_Biomass': 1000.0,
#  'EX_ca2_ex': 1000.0,
#  'EX_cl_ex': 1000.0,
#  'EX_co2_ex': 1000.0,
#  'EX_cobalt2_ex': 1000.0,
#  'EX_cu2_ex': 1000.0,
#  'EX_fe2_ex': 1000.0,
#  'EX_fe3_ex': 1000.0,
#  'EX_glc_DASH_D_ex': 0,
#  'EX_glyc_ex': 0,
#  'EX_h_ex': 1000.0,
#  'EX_h2o_ex': 1000.0,
#  'EX_k_ex': 1000.0,
#  'EX_mg2_ex': 1000.0,
#  'EX_mn2_ex': 1000.0,
#  'EX_mobd_ex': 1000.0,
#  'EX_nh4_ex': 1000.0,
#  'EX_ni2_ex': 1000.0,
#  'EX_o2_ex': 0,
#  'EX_pi_ex': 1000.0,
#  'EX_so4_ex': 1000.0,
#  'EX_succ_ex': 0,
#  'EX_zn2_ex': 1000.0,
#  'EX_ac_ex': 0,
#  'EX_etoh_ex': 1000.0,
#  'EX_for_ex': 1000.0,
#  'EX_h2_ex': 1000.0,
#  'EX_lac_ex': 1000.0,
#  'EX_4CRSOL_ex': 1000.0,
#  'EX_5DRIB_ex': 1000.0,
#  'EX_AMOB_ex': 1000.0,
#  'EX_MTHTHF_ex': 1000.0,
#  'EX_meoh_ex': 1000.0}

# %%
growth_data_core = []
for c in c_sources:
    for e in e_acceptors + ['fermentation']:
        tmp_medium = my_medium.copy()
        tmp_medium[c] = 10
        if e != 'fermentation':
            tmp_medium[e] = 1000

        core_model.medium = tmp_medium
        opt = core_model.optimize()
        mu = opt.objective_value
        growth_data_core.append(dict(
            e_acceptor=e,
            c_source=c,
            growth_rate_hr=mu,
            maintenance=opt.fluxes['ATPM'],
        ))

core_results_df = pd.DataFrame(growth_data_core)
# Out:
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# /opt/miniconda3/lib/python3.8/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)

# %%
core_results_df
# Out:
#      e_acceptor          c_source  growth_rate_hr  maintenance
# 0      EX_o2_ex  EX_glc_DASH_D_ex    9.750579e-01          5.0
# 1  fermentation  EX_glc_DASH_D_ex    2.691588e-01          5.0
# 2      EX_o2_ex        EX_glyc_ex    5.551688e-01          5.0
# 3  fermentation        EX_glyc_ex    5.809203e-16          5.0
# 4      EX_o2_ex          EX_ac_ex    2.367934e-01          5.0
# 5  fermentation          EX_ac_ex    1.368552e-17          5.0
# 6      EX_o2_ex        EX_succ_ex    4.847596e-01          5.0
# 7  fermentation        EX_succ_ex    2.089400e-16          5.0
